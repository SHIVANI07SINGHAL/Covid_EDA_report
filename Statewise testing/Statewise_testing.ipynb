# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('StatewiseTestingDetails.csv')

# %%
df.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0

# %%
#slicing between rows
df[11:23]
# Out:
#           Date                        State  TotalSamples Negative  Positive
# 11  2020-05-25  Andaman and Nicobar Islands        7363.0      NaN      33.0
# 12  2020-05-26  Andaman and Nicobar Islands        7448.0      NaN      33.0
# 13  2020-05-27  Andaman and Nicobar Islands        7499.0      NaN      33.0
# 14  2020-05-28  Andaman and Nicobar Islands        7519.0      NaN      33.0
# 15  2020-05-29  Andaman and Nicobar Islands        7567.0      NaN      33.0
# 16  2020-05-30  Andaman and Nicobar Islands        7567.0      NaN      33.0
# 17  2020-05-31  Andaman and Nicobar Islands        7706.0      NaN      33.0
# 18  2020-06-01  Andaman and Nicobar Islands        7805.0      NaN      33.0
# 19  2020-06-02  Andaman and Nicobar Islands        8086.0      NaN      33.0
# 20  2020-06-03  Andaman and Nicobar Islands        8295.0      NaN      33.0
# 21  2020-06-04  Andaman and Nicobar Islands        8413.0      NaN      33.0
# ...

# %%
#index of location
df.iloc[[11,34,67]]
# Out:
#           Date                        State  TotalSamples Negative  Positive
# 11  2020-05-25  Andaman and Nicobar Islands        7363.0      NaN      33.0
# 34  2020-06-17  Andaman and Nicobar Islands       12239.0      NaN      44.0
# 67  2020-07-20  Andaman and Nicobar Islands       20301.0      NaN     207.0

# %%
df[['State','Positive']].head()
# Out:
#                          State  Positive
# 0  Andaman and Nicobar Islands      12.0
# 1  Andaman and Nicobar Islands      27.0
# 2  Andaman and Nicobar Islands      33.0
# 3  Andaman and Nicobar Islands      33.0
# 4  Andaman and Nicobar Islands      33.0

# %%
df.ndim
df.shape
# Out:
# (15113, 5)

# %%
df.describe()
# Out:
#        TotalSamples      Positive
# count  1.511300e+04  5.589000e+03
# mean   4.675773e+06  5.444224e+04
# std    7.606151e+06  1.647919e+05
# min    5.800000e+01  0.000000e+00
# 25%    1.436260e+05  5.210000e+02
# 50%    7.701740e+05  4.595000e+03
# 75%    6.414658e+06  3.335200e+04
# max    5.933166e+07  1.638961e+06

# %%
df.describe(include='all')
# Out:
#               Date   State  TotalSamples Negative      Positive
# count        15113   15113  1.511300e+04     6657  5.589000e+03
# unique         462      36           NaN     6586           NaN
# top     2021-06-22  Kerala           NaN    39008           NaN
# freq            35     462           NaN        3           NaN
# mean           NaN     NaN  4.675773e+06      NaN  5.444224e+04
# std            NaN     NaN  7.606151e+06      NaN  1.647919e+05
# min            NaN     NaN  5.800000e+01      NaN  0.000000e+00
# 25%            NaN     NaN  1.436260e+05      NaN  5.210000e+02
# 50%            NaN     NaN  7.701740e+05      NaN  4.595000e+03
# 75%            NaN     NaN  6.414658e+06      NaN  3.335200e+04
# max            NaN     NaN  5.933166e+07      NaN  1.638961e+06

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
df.head(100)
# Out:
#           Date                        State  TotalSamples Negative  Positive
# 0   2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1   2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2   2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3   2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4   2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# 5   2020-05-19  Andaman and Nicobar Islands        6965.0      NaN      33.0
# 6   2020-05-20  Andaman and Nicobar Islands        7082.0      NaN      33.0
# 7   2020-05-21  Andaman and Nicobar Islands        7167.0      NaN      33.0
# 8   2020-05-22  Andaman and Nicobar Islands        7263.0      NaN      33.0
# 9   2020-05-23  Andaman and Nicobar Islands        7327.0      NaN      33.0
# 10  2020-05-24  Andaman and Nicobar Islands        7327.0      NaN      33.0
# ...

# %%
df.dtypes
# Out:
# Date             object
# State            object
# TotalSamples    float64
# Negative         object
# Positive        float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# State                   object
# TotalSamples           float64
# Negative                object
# Positive               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15113 entries, 0 to 15112
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          15113 non-null  datetime64[ns]
#  1   State         15113 non-null  object
#  2   TotalSamples  15113 non-null  float64
#  3   Negative      6657 non-null   object
#  4   Positive      5589 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 590.5+ KB

# %%
df.isnull().sum()
# Out:
# Date               0
# State              0
# TotalSamples       0
# Negative        8456
# Positive        9524
# dtype: int64

# %%
df.groupby(['State']).mean()
# Out:
#                                           TotalSamples       Positive
# State
# Andaman and Nicobar Islands               1.730542e+05    3987.064904
# Andhra Pradesh                            9.110843e+06   31376.097561
# Arunachal Pradesh                         2.992285e+05     441.767241
# Assam                                     5.142307e+06   18122.728070
# Bihar                                     1.348311e+07   14756.706349
# Chandigarh                                1.779845e+05     466.102362
# Chhattisgarh                              3.294967e+06    3713.150794
# Dadra and Nagar Haveli and Daman and Diu  3.720157e+04    1119.271523
# Delhi                                     7.707338e+06   55676.203252
# Goa                                       3.615382e+05    2129.448000
# Gujarat                                   8.286205e+06   46839.280702
# Haryana                                   3.681120e+06   19122.655405
# ...

# %%
df1=df.groupby(['Date']).sum()

# %%
df1.head(50)
# Out:
#             TotalSamples  Positive
# Date
# 2020-04-01       11245.0     302.0
# 2020-04-02       14906.0     510.0
# 2020-04-03       20130.0     898.0
# 2020-04-04       10786.0     306.0
# 2020-04-05       44139.0    1201.0
# 2020-04-06       29698.0    1196.0
# 2020-04-07       76933.0    2974.0
# 2020-04-08       63058.0    2473.0
# 2020-04-09      109609.0    4681.0
# 2020-04-10      155696.0    6490.0
# 2020-04-11      171571.0    7830.0
# 2020-04-12      191530.0    8380.0
# 2020-04-13      210051.0    9389.0
# 2020-04-14      235088.0   10408.0
# 2020-04-15      261132.0   11409.0
# 2020-04-16      299725.0   12348.0
# 2020-04-17      333455.0   13437.0
# 2020-04-18      363532.0   14481.0
# 2020-04-19      423547.0   16723.0
# 2020-04-20      446947.0   17147.0
# 2020-04-21      486257.0   18533.0
# 2020-04-22      530890.0   19912.0
# 2020-04-23      574814.0   20749.0
# 2020-04-24      638084.0   22995.0
# 2020-04-25      686738.0   24387.0
# ...

# %%
plt.rcParams['figure.figsize'] = [12, 8]
df1['Positive'].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df1.tail()
# Out:
#             TotalSamples  Positive
# Date
# 2021-07-02   447143589.0  419895.0
# 2021-07-03   448674293.0  420383.0
# 2021-07-04   451047274.0  420867.0
# 2021-07-05   452775075.0  421139.0
# 2021-07-06   454274654.0  414186.0

# %%
import datetime
start=datetime.datetime(2020,4,17)
end=datetime.datetime(2021,7,6)

# %%
index=pd.date_range(start,end,freq='M')

# %%
index
# Out:
# DatetimeIndex(['2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31',
#                '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#                '2020-12-31', '2021-01-31', '2021-02-28', '2021-03-31',
#                '2021-04-30', '2021-05-31', '2021-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
df2=df.head(1500)

# %%
plt.bar(df2.State,df2.Positive,color=['r'])
plt.xlabel('State')
plt.ylabel('Positive')
plt.title('Bar graph')
# Out:
# Text(0.5, 1.0, 'Bar graph')

# %%
#scatter plot
plt.scatter(df2['Date'],df2['Positive'])

# %%
#Seaborn Visulization
df3=df2.head();
sns.barplot(x='Date',y='Positive',data=df3)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Positive'>
